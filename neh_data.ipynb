# %%
import pandas as pd
import csv

# %%
grants_1990s = pd.read_csv('https://raw.githubusercontent.com/ejt2703/neh_grant_data_gender/main/NEH_Grants1990s.csv')

# %%
grants_2000s = pd.read_csv('https://raw.githubusercontent.com/ejt2703/neh_grant_data_gender/refs/heads/main/NEH_Grants2000s.csv')

# %%
grants_2010s = pd.read_csv('https://raw.githubusercontent.com/ejt2703/neh_grant_data_gender/refs/heads/main/NEH_Grants2010s.csv')

# %%
grants_2020s = pd.read_csv('https://raw.githubusercontent.com/ejt2703/neh_grant_data_gender/refs/heads/main/NEH_Grants2020s.csv')

# %%
# AppNumber,ApplicantType,Institution,OrganizationType,InstCity,InstState,InstPostalCode,InstCountry,CongressionalDistrict,Latitude,Longitude,CouncilDate,YearAwarded,ProjectTitle,Program,Division,ApprovedOutright,ApprovedMatching,AwardOutright,AwardMatching,OriginalAmount,SupplementAmount,BeginGrant,EndGrant,ProjectDesc,ToSupport,PrimaryDiscipline,SupplementCount,Supplements,ParticipantCount,Participants,DisciplineCount,Disciplines

# %%
combined_grants = [grants_1990s, grants_2000s, grants_2010s, grants_2020s]
combined_df = pd.concat(combined_grants, ignore_index=True)

# %%
combined_df.to_csv("combined_df.csv", index=False)

# %% [markdown]
# I want to:
# 1. Create a new column called "gender_focus".
# 2. Filter for projects that relate to gender using a list of keywords that appear in either the ProjectTitle, ProjectDesc, or ToSupport columns, or that are listed explicitly as a gender studies project in the PrimaryDiscipline or Disciplines columns.
# 3. Add a "yes", "no", or "unknown" to the "gender_focus" column based on the result.

# %%
gender_keywords = [
'GENDER',
 'GENDERED',
 'GENDERING',
 'SEXUALITY',
 'SEXUALIZE',
 'SEXUALIZATION',
 'SEXUAL',
 'LGBTQ+',
 'LGBT',
 'LGBT+',
 'LGBTQIA+',
 'LGBTQIA',
 'LESBIAN',
 'GAY',
 'BISEXUAL',
 'ASEXUAL',
 'TRANSGENDER',
 'QUEER',
 'QUEERED',
 'QUEERING',
 'WOMAN',
 'WOMEN',
 'WOMANHOOD',
 'FEMALE',
 'FEMALES',
 'GIRL',
 'GIRLS',
 'GIRLHOOD',
 'FEMININE',
 'FEMININITY',
 'MASCULINE',
 'MASCULINITY',
 'FEMINISM',
 'FEMINIST',
 'FEMINISMS',
 'PATRIARCHY',
 'PATRIARCHAL',
 'HETERONORMATIVE',
 'HETERONORMATIVITY',
 'CISGENDER',
 'CISNORMATIVE',
 'CISNORMATIVITY',
 'EMILY DICKINSON',
 'FRANCES PERKINS',
 'SHIRLEY CHISHOLM',
 'MARY SHELLEY',
 'CATHARINE',
 'SOR JUANA',
 'ESTHER',
 'HANNAH',
 'LOUISA',
 'ISADORA',
 'MME DE STAEL',
 'OCTAVIA BUTLER',
 'AGNES',
 'GABRIELA MISTRAL',
 'ISABEL',
 'LUISA',
 'UNA JEFFERS',
 'HATSHEPSUT',
 'MINÉ OKUBO',
 'BERNARDINE',
 'GLBT',
 'GODDESS',
 'ELIZABETH',
 'CLEOPATRA',
 'CHARLOTTE',
 'BRONTE',
 'WOOLF',
 'TONI MORRISON',
 'MAYA ANGELOU',
 'BELL HOOKS',
 'ALICE WALKER',
 'ANNA JULIA COOPER',
 'ZORA NEALE HURSTON',
 'FRIDA KAHLO',
 'CELIA CRUZ',
 'RIGOBERTA MENCHÚ',
 'RIGOBERTA MENCHU',
 'SANDRA CISNEROS',
 'GLORIA ANZALDÚA',
 'GLORIA ANZALDUA',
 'JULIA DE BURGOS',
 'ESMERALDA SANTIAGO',
 'LORNA DEE CERVANTES',
 'LORRAINE HANSBERRY',
 'ASSATA SHAKUR',
 'CHIMAMANDA NGOZI ADICHIE',
 'LESLIE MARMON SILKO',
 'LOUISE ERDRICH',
 'JOY HARJO',
 'LINDA HOGAN',
 'ROBIN WALL KIMMERER',
 'WINONA LADUKE',
 'AUNG SAN SUU KYI',
 'YOKO ONO',
 'MAXINE HONG KINGSTON',
 'AMY TAN',
 'CATHY PARK HONG',
 'OCEAN VUONG',
 'THERESA HAK KYUNG CHA',
 'GAYATRI SPIVAK',
 'GHADA AL-SAMMAN',
 'ASSIA DJEBAR',
 'LEILA ABOULELA',
 'MARJANE SATRAPI',
 'FATEMA MERNISSI',
 'SAPPHO',
 'SAPPHIC',
 'SAPPHISM',
 'HAUNANI-KAY TRASK',
 'TERESIA TEAIWA',
 'SELINA TUSITALA MARSH',
 'PATRICIA GRACE',
 'GRACE MERA MOLISA',
 'SUSAN',
 'DAUGHTER',
 'ADELAIDE JOHNSON',
 'ALICE CHENOWETH',
 'HELEN HAMILTON GARDENER,ALMA THOMAS',
 'AMY LOWELL',
 'ANNA JULIA COOPER',
 'BEATRIX POTTER',
 'BELLE DA COSTA GREENE',
 'CHARLOTTE PERKINS GILMAN',
 'EUDORA WELTY',
 'ESMERALDA SANTIAGO',
 'HANNAH CRAFTS',
 'ISABELLA STEWART GARDNER',
 'JANE ADDAMS',
 'JOAN OF ARC',
 'JULIA ALVAREZ',
 'JULIA ÁLVAREZ',
 'LOIE FULLER',
 'LOÏE FULLER',
 'KATHARINE',
 'LA MALINCHE',
 'MFK FISHER',
 'M.F.K. FISHER',
 'MARTHA MOORE BALLARD',
 'MARY CASSATT',
 'MOTHER CABRINI',
 'MOTHER FRANCES XAVIER CABRINI',
 'MOTHER THERESA',
 'NATALIE DE BLOIS',
 'RUTH BADER GINSBURG',
 'SYLVIA PLATH',
 'URSULA PARROTT',
 'URSULA LE GUIN',
 'URSULA K. LE GUIN',
 'URSULA K LE GUIN',
 'WINONA LADUKE'
 ]

# %%
gender_discipline = [
    "GENDER STUDIES",
    "WOMEN'S HISTORY"
]

# %%
info_columns = ['ProjectTitle', 'ProjectDesc', 'ToSupport']
discipline_columns = ['PrimaryDiscipline', 'Disciplines']

# %%
# Below is my original code to establish a gender_filter. It didn't work because pandas needed to evaluate it as a string, which is was not.
# def gender_filter(row):
#    for column in info_columns:
#        if any(keyword in row[column].upper() for keyword in gender_keywords):
#            return True
#    for column in discipline_columns:
#        if any(keyword in row[column].upper() for keyword in gender_discipline):
#            return True
#    return False

# Below, the code is revised to convert each row[column] to a string before applying the upper() method.

def gender_filter(row):
    for column in info_columns:
        if any(keyword in str(row[column]).upper() for keyword in gender_keywords):
            return True
    for column in discipline_columns:
        if any(keyword in str(row[column]).upper() for keyword in gender_discipline):
            return True
    return False

# %%
combined_df['gender_focus'] = combined_df.apply(gender_filter, axis=1)

# apply lets me run the function across rows or columns
# axis=1 tells pandas to specifically apply the function to each row of the dataframe

# %%
len(combined_df)
# Out:
# 34632

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34632 entries, 0 to 34631
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AppNumber              34632 non-null  object
#  1   ApplicantType          34632 non-null  int64
#  2   Institution            34632 non-null  object
#  3   OrganizationType       34632 non-null  object
#  4   InstCity               34632 non-null  object
#  5   InstState              34632 non-null  object
#  6   InstPostalCode         34628 non-null  object
#  7   InstCountry            34632 non-null  object
#  8   CongressionalDistrict  34632 non-null  int64
#  9   Latitude               34632 non-null  object
#  10  Longitude              34632 non-null  object
#  11  CouncilDate            34632 non-null  object
#  12  YearAwarded            34632 non-null  int64
#  13  ProjectTitle           34632 non-null  object
#  14  Program                34632 non-null  object
#  15  Division               34632 non-null  object
#  16  ApprovedOutright       34632 non-null  float64
#  17  ApprovedMatching       34632 non-null  float64
#  18  AwardOutright          34632 non-null  float64
#  19  AwardMatching          34632 non-null  float64
#  20  OriginalAmount         34632 non-null  float64
#  21  SupplementAmount       34632 non-null  float64
#  22  BeginGrant             34632 non-null  object
#  23  EndGrant               34632 non-null  object
#  24  ProjectDesc            34632 non-null  object
#  25  ToSupport              34632 non-null  object
#  26  PrimaryDiscipline      34632 non-null  object
#  27  SupplementCount        34632 non-null  int64
#  28  Supplements            1044 non-null   object
#  29  ParticipantCount       34632 non-null  int64
#  30  Participants           33629 non-null  object
#  31  DisciplineCount        34632 non-null  int64
#  32  Disciplines            34192 non-null  object
#  33  gender_focus           34632 non-null  bool
# dtypes: bool(1), float64(6), int64(6), object(21)
# memory usage: 8.8+ MB

# %% [markdown]
# Now, combined_df has a gender_focus column, in which I can assess projects that have a gender focus (TRUE) or not (FALSE) based on a list of gender_keywords and gender_disciplines.
#
# Now I want to answer the following quantifiable questions:
# 1. How many funded projects between 1990 and 2025 had a gender focus? What percentage?
# 2. How has the number of gender-related projects changed over the years?
# 3. What states have conducted the most gender-related projects?
# 4. How much funding in Outright Awards have gender-related projects received between 1990 and 2025?
# 5. About how much funding goes to gender-related projects each year? (median or mean)

# %%
combined_df['gender_focus'].value_counts()
# Out:
# gender_focus
# False    31396
# True      3236
# Name: count, dtype: int64

# %%
gender_focus_by_year = combined_df.groupby(["YearAwarded", "gender_focus"]).size().rename("projects").reset_index()

# %%
gender_focus_by_year
# Out:
#     YearAwarded  gender_focus  projects
# 0          1980         False         1
# 1          1989         False       256
# 2          1989          True        15
# 3          1990         False      1820
# 4          1990          True       114
# ..          ...           ...       ...
# 70         2023          True       124
# 71         2024         False       657
# 72         2024          True       109
# 73         2025         False       161
# 74         2025          True        13
#
# [75 rows x 3 columns]

# %% [markdown]
# Next, I want to compare overall trends in the NEH's gender priorities with the recent funding cuts.
#
# 1. Of the projects that had their funding cut in April 2025, how many had a gender_focus? What percentage?
# 2. What were the names of those projects?
# 3. How much funding did the projects whose grants were cancelled receive? How does that number compare to the average or median amount of funding that has been awarded to gender-related projects per year?

# %% [markdown]
# Lastly, I want to take a look at the new grants that were issued in August. The NYT reported that many of these grants promote American ideals and focus on presidents, statesmen, and canonical figures in American history.
#
# 1. Of the new grants that were issued, how many supported projects with a gender_focus? What percentage?
# 2. How much funding did gender_related projects receive?
# 3. What primary disciplines did each new project belong too? What is the most popular discipline?
